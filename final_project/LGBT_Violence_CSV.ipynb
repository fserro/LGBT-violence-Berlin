# %% [markdown]
# # This notebook checks and exports pickled DataFrames to CSV files

# %%
import pickle

# %%
# load df_lgbt
with open('pickles/df_lgbt.pickle', 'rb') as f:
    df_lgbt = pickle.load(f)

# %%
# load df_map
with open('pickles/df_map_test.pickle', 'rb') as f:
    df_map = pickle.load(f)

# %%
# load df_complete
with open('pickles/df_complete.pickle', 'rb') as f:
    df_complete = pickle.load(f)

# %%
df_lgbt.sort_values('Date')
# Out:
#             Date                    District  \
# 2675  2014-02-11  Charlottenburg-Wilmersdorf
# 2668  2014-02-14                       Mitte
# 2656  2014-02-21                     Spandau
# 2645  2014-02-24                    Neukölln
# 2587  2014-03-15                      Pankow
# ...          ...                         ...
# 20804 2021-05-20                       Mitte
# 20780 2021-05-23    Friedrichshain-Kreuzberg
# 20756 2021-05-27                       Mitte
# 20753 2021-05-27                      Pankow
# 20746 2021-05-29                    Neukölln
#
#                                                   Header  \
# 2675     Homosexuellenfeindlicher Angriff am Bahnhof Zoo
# 2668   Homophobe Aggression und Beleidigung gegen Dem...
# 2656   Rassistischer Angriff nahe Erstaufnahmeeinrich...
# 2645                    Mehrfach ins Gesicht geschlagen
# 2587                               Homophobe Beleidigung
# ...                                                  ...
# ...

# %%
df_map
# Out:
#             Date              District  \
# 1707  2014-11-29  Tempelhof-Schöneberg
# 1836  2014-10-26  Tempelhof-Schöneberg
# 1915  2014-10-03                 Mitte
# 1940  2014-09-24  Tempelhof-Schöneberg
# 1951  2014-09-21                Pankow
# ...          ...                   ...
# 15355 2019-06-09                 Mitte
# 16735 2019-01-27                 Mitte
# 19214 2020-06-14                 Mitte
# 4133  2015-05-18                 Mitte
# 14383 2019-09-30                 Mitte
#
#                                                   Header  \
# 1707                  Angriff aus transphober Motivation
# 1836                  Angriff aus transphober Motivation
# 1915     Homophobe Aggression gegen ein schwules Pärchen
# 1940                  Angriff aus transphober Motivation
# 1951         Homophober Angriff am S-Bahnhof Blankenburg
# ...                                                  ...
# 15355  Erneute Sachbeschädigung am Denkmal für die im...
# ...

# %% [markdown]
# ____

# %%
df_lgbt.to_csv('df_lgbt.csv', index=False)

# %%
df_map.to_csv('df_map.csv', index=False)

# %%
df_complete.to_csv('df_complete.csv', index=False)
